# %%
import sys
import numpy as np
import AllMethods.PercentileMethods as PMethods
#import OneDimMethods.OneDimMethods as OneDimMethods

def PercentileMethods(x, y = None, ECDF = False):
    PMethods.main(x, y, ECDF = ECDF)
    
if __name__ == '__main__':
    # Only changing the datasets is need to run the code. We plot and work with the data as (x[i],y[i]). 
    
    #This is for TLE / CEP
    #dataset_xaxis, dataset_yaxis = PMethods.generate_TLE('t',size = 20)
    #PercentileMethods(dataset_xaxis, dataset_yaxis)
    
    #This is for one dimensional data
    dataset = PMethods.generate_data('c',size = 20)
    PercentileMethods(dataset, ECDF = True)
    
    #print(PMethods.bounds(dataset_xaxis, dataset_yaxis, Method = 'binomial', perc = 0.9, CLevel = 90))
    #print(PMethods.bounds(dataset_xaxis, Method = 'binomial', perc = 0.9, CLevel = 90))
# Out:
# What percentile are you looking for, 50 or 90? 50
# What confidence level are you looking for? (0-100): 95
# Is your sample size: 20, (y or n)? y
# What type of scatterplot does your data most resemble? Plots of sample data are shown: Options are:
# 	normal (n)
# 	outliers(o)
# 	cluster(c)
# 	two (t)
# 	other
# Data Type: n
# We recommend using the VP method.
# What method would you like to use? Options are:
# 	(VP) Vysochanskij–Petunin
# 	(T) Tolerance
# 	(W) Weibull
# 	(B2) Binomial #2
# 	(BS) Binomial Smooth
# 	(ALL) All methods
# 	(AVG) Average of all methods [Not recommended]
#  Desired Method: vp
#
# The 50th percentile 95% confidence interval for the data relative to the origin using the vp method is: [12.9851 86.8207]
